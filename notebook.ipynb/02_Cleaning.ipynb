# %% [markdown]
# DAY---------------------------------------------------->2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Data/online_retail_II.csv")

df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
print("Shape:", df.shape)

df.info()
# Out:
# Shape: (1067371, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
missing = df.isnull().sum()

missing_percentage = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    "Missing Values": missing,
    "Percentage": missing_percentage
})

missing_df.sort_values("Missing Values", ascending=False)
# Out:
#              Missing Values  Percentage
# Customer ID          243007   22.766873
# Description            4382    0.410541
# StockCode                 0    0.000000
# Invoice                   0    0.000000
# Quantity                  0    0.000000
# InvoiceDate               0    0.000000
# Price                     0    0.000000
# Country                   0    0.000000

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 34335

# %%
df = df.drop_duplicates()

print("New Shape:", df.shape)
# Out:
# New Shape: (1033036, 8)

# %%
df = df.dropna(subset=["Customer ID"])

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# C:\Users\devar\AppData\Local\Temp\ipykernel_15720\2579964100.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\devar\AppData\Local\Temp\ipykernel_15720\2579964100.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\devar\AppData\Local\Temp\ipykernel_15720\2579964100.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %%
categorical_cols = df.select_dtypes(include="object").columns

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\devar\AppData\Local\Temp\ipykernel_15720\2833354607.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
df["Year"] = df["InvoiceDate"].dt.year

df["Month"] = df["InvoiceDate"].dt.month

df["Day"] = df["InvoiceDate"].dt.day

df["Weekday"] = df["InvoiceDate"].dt.day_name()

# %%
df = df[df["Quantity"] > 0]
df = df[df["Price"] > 0]

# %%
df = df[~df["Invoice"].astype(str).str.startswith("C")]

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

# %%
for col in numeric_cols:

    Q1 = df[col].quantile(0.25)

    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR

    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
print(df.shape)

df.info()

df.head()
# Out:
# (663373, 12)
# <class 'pandas.core.frame.DataFrame'>
# Index: 663373 entries, 0 to 1067369
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      663373 non-null  object
#  1   StockCode    663373 non-null  object
#  2   Description  663373 non-null  object
#  3   Quantity     663373 non-null  int64
#  4   InvoiceDate  663373 non-null  datetime64[ns]
#  5   Price        663373 non-null  float64
#  6   Customer ID  663373 non-null  float64
#  7   Country      663373 non-null  object
#  8   Year         663373 non-null  int32
#  9   Month        663373 non-null  int32
#  10  Day          663373 non-null  int32
#  11  Weekday      663373 non-null  object
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(1), object(5)
# memory usage: 58.2+ MB
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5  489434     22064           PINK DOUGHNUT TRINKET POT         24
#
#           InvoiceDate  Price  Customer ID         Country  Year  Month  Day  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12    1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12    1
# 5 2009-12-01 07:45:00   1.65      13085.0  United Kingdom  2009     12    1
#
#    Weekday
# 0  Tuesday
# 1  Tuesday
# 2  Tuesday
# 4  Tuesday
# 5  Tuesday

# %%
df.to_csv("online_retail_cleaned.csv", index=False)

print("Dataset Saved Successfully!")
# Out:
# Dataset Saved Successfully!
