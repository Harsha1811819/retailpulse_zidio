# %%
# !pip install streamlit
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\devar\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ...
